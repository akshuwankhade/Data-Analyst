# %%
# Type Casting >> The Process Of the Data type Change of a value or object in python known as Type casting.

# Convert string to int
test="5"
int_test=int(test)
int_test
# Out:
# 5

# %%
type(int_test)
# Out:
# int

# %%
# Convert int to String
a=10
a_int=str(a)
a_int
# Out:
# '10'

# %%
type(a_int)
# Out:
# str

# %%
# Convert float to int
b_float=2.5
c_int=int(b_float)
c_int
# Out:
# 2

# %%
type(c_int)
# Out:
# int

# %% [markdown]
#  # Explicit Type
#  Explicit Type conversion >> Conert data type using inbuilt function
#
#  1.String
#  2.Int
#  3.Float
#  4.Bool

# %%
# Conert Flot to int
x=12.5
y=int(12.5)
y
# Out:
# 12

# %%
type(y)
# Out:
# int

# %%
# Convert String to float

a="25.5"
b=float(a)
b
# Out:
# 25.5

# %%
type(b)
# Out:
# float

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False
