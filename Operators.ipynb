# %%
# What is operatoers>> Operatoers is special keywords to perform operations

# Arithmatic Operatoers
a=5
b=10
a+b
# Out:
# 15

# %%
add=10+20
print(add)
# Out:
# 30

# %%
# Modulus Operators

2**3 #2*2*2
# Out:
# 8

# %%
3**2 # 3*3
# Out:
# 9

# %%
# Comparison operatoers>> Compares two value >> return a boolean value
2 == 2
# Out:
# True

# %%
2 >1
# Out:
# True

# %%
10<15
# Out:
# True

# %%
10>15
# Out:
# False

# %%
10>=10
# Out:
# True

# %%
10<=10
# Out:
# True

# %%
# Logical Operators
# And Operator

True and True
# Out:
# True

# %%
# OR Operator

True or Flase
# Out:
# True

# %%
#Assignment Operators:
a=10

# %%
a
# Out:
# 10

# %%
a+5
# Out:
# 15

# %%
a
# Out:
# 10

# %%
print(a)
# Out:
# 10

# %%
# Membership Operators:

a = "PWSkillS"

"P" in a
# Out:
# True

# %%
"Am" in "I Am joy"
# Out:
# True

# %%
a = ["Data","Science", 'Ajay"']

# %%
"data" in a
# Out:
# False

# %%
# Identity Operators:

a="PWskills"
b="Data"
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
# Bitwise Operator

10 & 10
# Out:
# 10

# %%
18 & 3
# Out:
# 2

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(2)
# Out:
# '0b10'
